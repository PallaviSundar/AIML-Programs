# %% [markdown]
# <a href="https://colab.research.google.com/github/PallaviSundar/AIML-Programs/blob/main/Pandas_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### pandas

# %%
import pandas as pd
green_ai_data = {
    'College': ['ABC University', 'XYZ Institute', 'Tech Valley', 'GreenField College',
 'EcoTech'],
    'Solar_Panels': [25, 18, 32, 20, 28],
    'Energy_Saved_kWh': [1200, 950, 1500, 1100, 1300],
    'Student_Participants': [200, 150, 300, 180, 220]
 }
df_green = pd.DataFrame(green_ai_data)
print(df_green)
# Out:
#               College  Solar_Panels  Energy_Saved_kWh  Student_Participants
# 0      ABC University            25              1200                   200
# 1       XYZ Institute            18               950                   150
# 2         Tech Valley            32              1500                   300
# 3  GreenField College            20              1100                   180
# 4             EcoTech            28              1300                   220

# %%
funding_data = {
    'College': ['ABC University', 'XYZ Institute', 'Tech Valley', 'GreenField College','EcoTech'],
    'Funding_Received': [500000, 300000, 700000, 400000, 550000],
    'Funding_Source': ['Govt', 'Private', 'Govt', 'NGO', 'Private']
 }
df_funding = pd.DataFrame(funding_data)
print(df_funding)
# Out:
#               College  Funding_Received Funding_Source
# 0      ABC University            500000           Govt
# 1       XYZ Institute            300000        Private
# 2         Tech Valley            700000           Govt
# 3  GreenField College            400000            NGO
# 4             EcoTech            550000        Private

# %%
print(df_green.shape)
print(df_green.info())
# Out:
# (5, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   College               5 non-null      object
#  1   Solar_Panels          5 non-null      int64
#  2   Energy_Saved_kWh      5 non-null      int64
#  3   Student_Participants  5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 292.0+ bytes
# None

# %%
print(df_funding.shape)
print(df_funding.info())
# Out:
# (5, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   College           5 non-null      object
#  1   Funding_Received  5 non-null      int64
#  2   Funding_Source    5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes
# None

# %%
print(df_green.describe())
# Out:
#        Solar_Panels  Energy_Saved_kWh  Student_Participants
# count      5.000000          5.000000              5.000000
# mean      24.600000       1210.000000            210.000000
# std        5.727128        207.364414             56.568542
# min       18.000000        950.000000            150.000000
# 25%       20.000000       1100.000000            180.000000
# 50%       25.000000       1200.000000            200.000000
# 75%       28.000000       1300.000000            220.000000
# max       32.000000       1500.000000            300.000000

# %%
print(df_funding.describe())
# Out:
#        Funding_Received
# count          5.000000
# mean      490000.000000
# std       151657.508881
# min       300000.000000
# 25%       400000.000000
# 50%       500000.000000
# 75%       550000.000000
# max       700000.000000

# %%
print(df_green.head())
# Out:
#               College  Solar_Panels  Energy_Saved_kWh  Student_Participants
# 0      ABC University            25              1200                   200
# 1       XYZ Institute            18               950                   150
# 2         Tech Valley            32              1500                   300
# 3  GreenField College            20              1100                   180
# 4             EcoTech            28              1300                   220

# %%
print(df_funding.head())
# Out:
#               College  Funding_Received Funding_Source
# 0      ABC University            500000           Govt
# 1       XYZ Institute            300000        Private
# 2         Tech Valley            700000           Govt
# 3  GreenField College            400000            NGO
# 4             EcoTech            550000        Private

# %%
print(df_green[df_green["Solar_Panels"] >20])
# Out:
#           College  Solar_Panels  Energy_Saved_kWh  Student_Participants
# 0  ABC University            25              1200                   200
# 2     Tech Valley            32              1500                   300
# 4         EcoTech            28              1300                   220

# %%
print(df_green[df_green["Energy_Saved_kWh"] > 1200])
# Out:
#        College  Solar_Panels  Energy_Saved_kWh  Student_Participants
# 2  Tech Valley            32              1500                   300
# 4      EcoTech            28              1300                   220

# %%
df_green['energy_per_student']= df_green['Energy_Saved_kWh']+df_green['Student_Participants']
df
# Out:
#               College  Solar_Panels  Energy_Saved_kWh  Student_Participants
# 0      ABC University            25              1200                   200
# 1       XYZ Institute            18               950                   150
# 2         Tech Valley            32              1500                   300
# 3  GreenField College            20              1100                   180
# 4             EcoTech            28              1300                   220

# %%
merge_df_green_and_df_funding = pd.merge(df_green,df_funding)
df_green.rename(columns={'Energy_Saved_kWh':'EnergySaved(kWh)'}, inplace=True)

df_funding.rename(columns={'Funding_Received':'Funding(INR)'}, inplace=True)

merge_df_green_and_df_funding.to_csv('green_ai_final.csv',index=False)
df_green
# Out:
#               College  Solar_Panels  EnergySaved(kWh)  Student_Participants  \
# 0      ABC University            25              1200                   200
# 1       XYZ Institute            18               950                   150
# 2         Tech Valley            32              1500                   300
# 3  GreenField College            20              1100                   180
# 4             EcoTech            28              1300                   220
#
#    energy_per_student
# 0                1400
# 1                1100
# 2                1800
# 3                1280
# 4                1520

# %%
merge_df_green_and_df_funding = pd.merge(df_green,df_funding)
df_green.rename(columns={'Energy_Saved_kWh':'EnergySaved(kWh)'}, inplace=True)
df_green
# Out:
#               College  Solar_Panels  EnergySaved(kWh)  Student_Participants  \
# 0      ABC University            25              1200                   200
# 1       XYZ Institute            18               950                   150
# 2         Tech Valley            32              1500                   300
# 3  GreenField College            20              1100                   180
# 4             EcoTech            28              1300                   220
#
#    energy_per_student
# 0                1400
# 1                1100
# 2                1800
# 3                1280
# 4                1520

# %%
df_green.to_csv("green_energy_data.csv", index=False)
df_green
# Out:
#               College  Solar_Panels  EnergySaved(kWh)  Student_Participants  \
# 0      ABC University            25              1200                   200
# 1       XYZ Institute            18               950                   150
# 2         Tech Valley            32              1500                   300
# 3  GreenField College            20              1100                   180
# 4             EcoTech            28              1300                   220
#
#    energy_per_student
# 0                1400
# 1                1100
# 2                1800
# 3                1280
# 4                1520
