# %% [markdown]
# <a href="https://colab.research.google.com/github/PallaviSundar/AIML-Programs/blob/main/TSNE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/climate data.csv')
df
# Out:
#       temperature  precipitation   humidity  co2_levels  wind_speed  \
# 0       17.483571     981.882760  40.290589  429.955082    7.747558
# 1       14.308678     654.528792  50.808133  338.392099    1.635120
# 2       18.238443     607.711318  88.206106  405.580543    7.408273
# 3       22.615149     641.413967  76.847271  353.561850    2.255336
# 4       13.829233    1374.304042  46.955450  330.552974    6.331719
# ...           ...            ...        ...         ...         ...
# 9995    21.505510    1524.406697  52.797263  422.119236   14.194309
# 9996     5.008275    1774.867153  65.575385  391.016348    7.487838
# 9997    11.473416     823.585236  70.302313  394.083183    7.472625
# 9998    17.478828    1630.739393  68.710204  425.080224   11.627498
# 9999    18.221942    1822.032860  81.795935  522.296947   11.341150
#
#       sea_level_rise
# 0           2.257752
# 1           3.027678
# 2           2.956763
# 3           3.169446
# 4           2.627995
# ...

# %%
df.head()
# Out:
#    temperature  precipitation   humidity  co2_levels  wind_speed  \
# 0    17.483571     981.882760  40.290589  429.955082    7.747558
# 1    14.308678     654.528792  50.808133  338.392099    1.635120
# 2    18.238443     607.711318  88.206106  405.580543    7.408273
# 3    22.615149     641.413967  76.847271  353.561850    2.255336
# 4    13.829233    1374.304042  46.955450  330.552974    6.331719
#
#    sea_level_rise
# 0        2.257752
# 1        3.027678
# 2        2.956763
# 3        3.169446
# 4        2.627995

# %%
df.tail()
# Out:
#       temperature  precipitation   humidity  co2_levels  wind_speed  \
# 9995    21.505510    1524.406697  52.797263  422.119236   14.194309
# 9996     5.008275    1774.867153  65.575385  391.016348    7.487838
# 9997    11.473416     823.585236  70.302313  394.083183    7.472625
# 9998    17.478828    1630.739393  68.710204  425.080224   11.627498
# 9999    18.221942    1822.032860  81.795935  522.296947   11.341150
#
#       sea_level_rise
# 9995        2.734895
# 9996        2.362891
# 9997        4.229241
# 9998        1.638339
# 9999        2.914624

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   temperature     10000 non-null  float64
#  1   precipitation   10000 non-null  float64
#  2   humidity        10000 non-null  float64
#  3   co2_levels      10000 non-null  float64
#  4   wind_speed      10000 non-null  float64
#  5   sea_level_rise  10000 non-null  float64
# dtypes: float64(6)
# memory usage: 468.9 KB

# %%
df.describe()
# Out:
#         temperature  precipitation      humidity    co2_levels    wind_speed  \
# count  10000.000000   10000.000000  10000.000000  10000.000000  10000.000000
# mean      14.989320    1260.701855     59.800946    399.235751      7.499818
# std        5.017312     434.258753     17.218698     50.666615      4.319268
# min       -4.612001     500.072186     30.004050    176.719807      0.001571
# 25%       11.637047     886.313191     44.881422    364.196499      3.772349
# 50%       14.987025    1266.903958     59.802869    399.395332      7.539326
# 75%       18.355404    1635.802052     74.485401    434.097279     11.225470
# max       34.631189    1999.887240     89.983925    586.391667     14.999354
#
#        sea_level_rise
# count    10000.000000
# mean         3.001789
# std          0.994839
# min         -0.421380
# 25%          2.335801
# 50%          3.006531
# 75%          3.669780
# max          6.745379

# %%
df.isnull().sum()
# Out:
# temperature       0
# precipitation     0
# humidity          0
# co2_levels        0
# wind_speed        0
# sea_level_rise    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data_scaled = scaler.fit_transform(df)
print(pd.DataFrame(data_scaled,columns=df.columns).head())
# Out:
#    temperature  precipitation  humidity  co2_levels  wind_speed  \
# 0     0.497154      -0.642090 -1.133148    0.606334    0.057360
# 1    -0.135665      -1.395950 -0.522296   -1.200923   -1.357867
# 2     0.647615      -1.503765  1.649752    0.125233   -0.021196
# 3     1.519979      -1.426152  0.990039   -0.901505   -1.214267
# 4    -0.231228       0.261613 -0.746058   -1.355650   -0.270453
#
#    sea_level_rise
# 0       -0.747935
# 1        0.026025
# 2       -0.045261
# 3        0.168535
# 4       -0.375752

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
minmax_scaler=scaler.fit_transform(df)
print(pd.DataFrame(minmax_scaler,columns=df.columns).head())
# Out:
#    temperature  precipitation  humidity  co2_levels  wind_speed  \
# 0     0.563042       0.321247  0.171500    0.618142    0.516475
# 1     0.482139       0.102984  0.346851    0.394639    0.108919
# 2     0.582278       0.071768  0.970360    0.558644    0.493853
# 3     0.693806       0.094239  0.780982    0.431668    0.150273
# 4     0.469922       0.582893  0.282618    0.375503    0.422072
#
#    sea_level_rise
# 0        0.373827
# 1        0.481258
# 2        0.471363
# 3        0.501039
# 4        0.425489

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2,perplexity=30,n_iter=300,random_state=42)
tsne_data = tsne.fit_transform(df)
data_tsne_df = pd.DataFrame(tsne_data,columns=['t-SNE-1','t-SNE-2'])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.scatterplot(x='t-SNE-1',y='t-SNE-2',data=data_tsne_df,palette='coolwarm',s=70,edgecolor='k',alpha=0.7)
plt.title('t-SNE Visualization of Climate Data')
plt.xlabel('t-SNE-1')
plt.ylabel('t-SNE-2')
plt.show()
# Out:
# /tmp/ipython-input-282014896.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='t-SNE-1',y='t-SNE-2',data=data_tsne_df,palette='coolwarm',s=70,edgecolor='k',alpha=0.7)
